# %% [markdown]
# <a href="https://colab.research.google.com/github/dikshap07/Algorithms-and-Data-Structures/blob/master/Stacks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###A stack is a linear data structure that stores items in a Last-In/First-Out (LIFO) or First-In/Last-Out (FILO) manner. In stack, a new element is added at one end and an element is removed from that end only. The insert and delete operations are often called push and pop.

# %% [markdown]
# ##PROBLEM STATEMENT-01

# %% [markdown]
# Problem Statement:
# ![image.png](data:image/png;base64,...)

# %%
def stack(S):

  stack = []
  count = 0
  for char in S:
    

    if char in ['[','{','(']:

      stack.append(char)
      count +=1

    elif char not in ['[','{','(']:

      count +=1

      if char in [']','}',')']:

        if stack != []:
          
          top = stack.pop()

          if (top == '[' and char != ']') or (top == '{' and char != '}')  or (top == '(' and char != ')') :
            
            key =  S.index(char)
            return (key+1)

        else:

          return count

      else:
        
        count +=1
        continue

      

  if stack != []:

    return S.index(stack.pop()) + 1

  return 'Success'

# %%
S = '{}[]'
S_ = '(())'
s = '{[}'
u = 'foo(bar);'
k = '({})}'
h = 'foo(bar[i);'

stack(s)
# Out:
# 3
